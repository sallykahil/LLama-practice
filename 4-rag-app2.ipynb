# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2TokenizerFast

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_classic.chains.question_answering import load_qa_chain
from langchain_classic.chains import ConversationalRetrievalChain
from langchain_community.llms import Ollama
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_34472\116864048.py:14: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# C:\Users\dell\AppData\Local\Temp\ipykernel_34472\116864048.py:15: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2", temperature=0)

# %%
 

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
llm = Ollama(model="llama3.2", temperature=0)
 
text = "Hello world"
vector = embeddings.embed_query(text)
print(vector)
# Out:
# [-0.03447723388671875, 0.031023165211081505, 0.006734973751008511, 0.026108991354703903, -0.039362046867609024, -0.16030244529247284, 0.06692394614219666, -0.0064415112137794495, -0.04745052382349968, 0.014758817851543427, 0.07087530195713043, 0.05552754923701286, 0.019193369895219803, -0.026251282542943954, -0.01010951679199934, -0.02694047801196575, 0.022307446226477623, -0.022226616740226746, -0.1496925950050354, -0.017493078485131264, 0.007676276378333569, 0.054352231323719025, 0.0032544422429054976, 0.03172587975859642, -0.0846213772892952, -0.029405953362584114, 0.05159562826156616, 0.04812408611178398, -0.0033148485235869884, -0.05827920883893967, 0.04196930304169655, 0.022210706025362015, 0.128188818693161, -0.02233896777033806, -0.011656241491436958, 0.06292831897735596, -0.032876331359148026, -0.09122606366872787, -0.031175393611192703, 0.05269952118396759, 0.047034814953804016, -0.0842030942440033, -0.030056195333600044, -0.020744822919368744, 0.009517833590507507, -0.0037
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\dell\Desktop\SALLY\AI-Sally\Intro-LLMs\.venv\Scripts\python.exe

# %%
from langchain_community.document_loaders import PyPDFLoader, PyPDFDirectoryLoader
from langchain_community.embeddings import HuggingFaceEmbeddings

# %%
import urllib
import os
 
loader = PyPDFLoader(  "./the-three-shelters-tafseer-of-the-three-quls.pdf")

# %%
from pypdf import PdfReader, PdfWriter

reader = PdfReader("./the-three-shelters-tafseer-of-the-three-quls.pdf")
# If this works, save unencrypted:
writer = PdfWriter()
for page in reader.pages:
    writer.add_page(page)
writer.write(open("unencrypted.pdf", "wb"))
# Out:
# ---------------------------------------------------------------------------
# DependencyError                           Traceback (most recent call last)
# Cell In[26], line 7
#       5 writer = PdfWriter()
#       6 for page in reader.pages:
# ----> 7     writer.add_page(page)
#       8 writer.write(open("unencrypted.pdf", "wb"))
#
# File c:\Users\dell\Desktop\SALLY\AI-Sally\Intro-LLMs\.venv\Lib\site-packages\pypdf\_writer.py:611, in PdfWriter.add_page(self, page, excluded_keys)
#     593 """
#     594 Add a page to this PDF file.
#     595
#    (...)    608
#     609 """
#     610 assert self.flattened_pages is not None, "mypy"
# --> 611 return self._add_page(page, len(self.flattened_pages), excluded_keys)
#
# File c:\Users\dell\Desktop\SALLY\AI-Sally\Intro-LLMs\.venv\Lib\site-packages\pypdf\_writer.py:514, in PdfWriter._add_page(self, page, index, excluded_keys)
#     510 except Exception:
#     511     pass
#     513 page = cast(
# ...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from transformers import GPT2TokenizerFast

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_classic.chains.question_answering import load_qa_chain
from langchain_classic.chains import ConversationalRetrievalChain
from langchain_community.llms import Ollama
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_34472\116864048.py:14: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# C:\Users\dell\AppData\Local\Temp\ipykernel_34472\116864048.py:15: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2", temperature=0)

# %%
pages = loader.load_and_split()
print(pages[0])

# SKIP TO STEP 2 IF YOU'RE USING THIS METHOD
chunks = pages
# Out:
# ---------------------------------------------------------------------------
# DependencyError                           Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 pages = loader.load_and_split()
#       2 print(pages[0])
#       4 # SKIP TO STEP 2 IF YOU'RE USING THIS METHOD
#
# File c:\Users\dell\Desktop\SALLY\AI-Sally\Intro-LLMs\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:86, in BaseLoader.load_and_split(self, text_splitter)
#      84 else:
#      85     text_splitter_ = text_splitter
# ---> 86 docs = self.load()
#      87 return text_splitter_.split_documents(docs)
#
# File c:\Users\dell\Desktop\SALLY\AI-Sally\Intro-LLMs\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# ...

# %%
type(chunks[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_community.vectorstores import FAISS
 

# Create vector database (same as before)
db = FAISS.from_documents(chunks, embeddings)

# %%
#HuggingFace BGE (often better quality)
#from langchain_community.embeddings import HuggingFaceBgeEmbeddings

#embeddings = HuggingFaceEmbeddings(
 #   model_name="BAAI/bge-small-en-v1.5",
   # encode_kwargs={"normalize_embeddings": True}
#)

#db = FAISS.from_documents(chunks, embeddings)

# %%
query = "What is machine learning?"
docs = db.similarity_search(query)
docs[0]
# Out:
# Document(id='eab74859-6760-4a97-b7ae-dd4ef87a03ac', metadata={'producer': 'PyPDF', 'creator': 'Google', 'creationdate': '', 'title': 'sally kahil - Machine Learning – Supervised Learning: Theory and Practice - Certificate', 'source': './sally kahil - Machine Learning – Supervised Learning_ Theory and Practice - Certificate.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Certificate of Completion \nLara Wehbe\nAI Engineer - Fakker.ai - TheAIEngineers\nSALLY KAHIL\nAwarded to:\nAs a recognition of their successful participation and commitment to learning in the \ncourse:\n“Machine Learning – Supervised Learning: Theory and Practice” 🚀\nThis certificate is awarded as a token of appreciation for the time, effort, and \nprogress demonstrated throughout the training. 😁\nThe course was successfully completed on 2025-08, and forms an essential part of their \njourney toward mastering real-world AI engineering skills.')
